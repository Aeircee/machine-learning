# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
m = len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 2

# %%
i = 0 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# x^(0), y^(0)) = (1.0, 300.0)

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# set the title
plt.title("Housing Prices")
# set the y axis label
plt.ylabel("Price (in 1000s of dollars)")
# set the x axis label
plt.xlabel("Size (in 1000s of square feet)")
plt.show()

# %%
w = 100
b = 100
print(f"w : {w}")
print(f"b : {b}")
# Out:
# w : 100
# b : 100

# %%
def compute_model_output(x, w, b):
    """
    Computes the output of a linear model y = wx + b

    Args:
        x (ndarray): Input data, shape (m,)
        w (scalar): Weight parameter
        b (scalar): Bias parameter

    Returns:
        y (ndarray): Output of the model, shape (m,)
    """
    m = x.shape[0] # number of training examples
    f_wb = np.zeros(m) # initialize the model output to zeros
    for i in range(m):
        f_wb[i] = w * x[i] + b # compute the model output for each example
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b)
# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b', label='Our Prediction')
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='actual values')
# set the title
plt.title("Housing Prices")
# set the y axis label 
plt.ylabel("Price (in 1000s of dollars)")
# set the x axis label
plt.xlabel("Size (in 1000s of square feet)")
plt.legend()
plt.show()

# %%
w = 500.0
b = 100.0
x_i = 1.2
cost_1200sqft = w * x_i + b
print(f"${cost_1200sqft:.0f}K")
# Out:
# $700K
